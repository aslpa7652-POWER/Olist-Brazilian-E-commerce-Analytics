# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df_customer = pd.read_csv("/content/olist_customers_dataset.csv")
df_geography = pd.read_csv("/content/olist_geolocation_dataset.csv")
df_order_item = pd.read_csv("/content/olist_order_items_dataset.csv")
df_payments = pd.read_csv("/content/olist_order_payments_dataset.csv")
df_reviews = pd.read_csv("/content/olist_order_reviews_dataset.csv")
df_orders = pd.read_csv("/content/olist_orders_dataset.csv")
df_products = pd.read_csv("/content/olist_products_dataset.csv")
df_sallers = pd.read_csv("/content/olist_sellers_dataset.csv")
df_translation = pd.read_csv("/content/product_category_name_translation.csv")

# %%
df_order_item
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# # df_orders or df_order_item me order_id same hai to inko merge karte hai

# %%
master_data = pd.merge(df_orders,df_order_item , on="order_id", how="inner")

# %%
master_data.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# dtype: int64

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
master_data
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# # master_data or df_products me product id same hai to merge karte hai

# %%
master_data = pd.merge(master_data,df_products , on = "product_id" , how="inner")

# %%
master_data
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
master_data.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name            1603
# product_name_lenght              1603
# product_description_lenght       1603
# product_photos_qty               1603
# product_weight_g                   18
# product_length_cm                  18
# product_height_cm                  18
# product_width_cm                   18
# dtype: int64

# %%
master_data
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_customer
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# # master_data or df_customer me customer_id bhi same hai to isse bhi merge karte hai

# %%
master_data = pd.merge(master_data,df_customer,on="customer_id" , how="inner")

# %%
master_data.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# product_category_name            1603
# product_name_lenght              1603
# product_description_lenght       1603
# product_photos_qty               1603
# product_weight_g                   18
# product_length_cm                  18
# product_height_cm                  18
# product_width_cm                   18
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# ...

# %%
master_data
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112645  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112646  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112647  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112648  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_sallers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_translation
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# # master data me or df_reviews me order_id same hai to isse bhi merge karte hai

# %%
df_master = pd.merge(master_data , df_reviews, on="order_id" , how="inner")

# %%
df_master
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112367  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112368  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112369  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112370  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112371  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_master.isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                   15
# order_delivered_carrier_date      1184
# order_delivered_customer_date     2360
# order_estimated_delivery_date        0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# product_category_name             1598
# product_name_lenght               1598
# product_description_lenght        1598
# product_photos_qty                1598
# product_weight_g                    18
# product_length_cm                   18
# product_height_cm                   18
# product_width_cm                    18
# customer_unique_id                   0
# customer_zip_code_prefix             0
# ...

# %%
df_geography
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
df_master
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112367  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112368  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112369  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112370  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112371  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_payments.order_id.nunique()
# Out:
# 99440

# %% [markdown]
# # isme payment installment me hua hai to ek customer ke multiple payment hai

# %%
payment = df_payments.groupby(["order_id"])["payment_value"].sum()

# %%
payment
# Out:
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214     72.19
# 00018f77f2f0320c557190d7a144bdd3    259.83
# 000229ec398224ef6ca0657da4fc703e    216.87
# 00024acbcdf0a6daa1e931b038114c75     25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9    218.04
#                                      ...
# fffc94f6ce00a00581880bf54a75a037    343.40
# fffcd46ef2263f404302a634eb57f7eb    386.53
# fffce4705a9662cd70adb13d4a31832d    116.85
# fffe18544ffabc95dfada21779c9644f     64.71
# fffe41c64501cc87c801fd61db3f6244     55.79
# Name: payment_value, Length: 99440, dtype: float64

# %%
payment = df_payments.groupby(["order_id"])["payment_value"].sum().reset_index()

# %% [markdown]
# # df_master or payment me order_id same hai merge karte hai

# %%
df_master = pd.merge(df_master,payment,on="order_id",how="inner")

# %%
df_master
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112364  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112365  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112366  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112367  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112368  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_master.isnull().sum()
# Out:
# order_id                             0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_approved_at                   15
# order_delivered_carrier_date      1184
# order_delivered_customer_date     2360
# order_estimated_delivery_date        0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# shipping_limit_date                  0
# price                                0
# freight_value                        0
# product_category_name             1598
# product_name_lenght               1598
# product_description_lenght        1598
# product_photos_qty                1598
# product_weight_g                    18
# product_length_cm                   18
# product_height_cm                   18
# product_width_cm                    18
# customer_unique_id                   0
# customer_zip_code_prefix             0
# ...

# %%
df_sallers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_master.to_csv("olist_final_merge_data.csv", index=False)

# %%
dff= pd.read_csv("olist_final_merge_data.csv")

# %%
dff
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112364  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112365  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112366  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112367  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112368  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
from google.colab import files
files.download("olist_final_merge_data.csv")

# %%
row_data = pd.read_csv("/content/olist_final_merge_data.csv")
df = row_data.copy()

# %%
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112364  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112365  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112366  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112367  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112368  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_purchase_timestamp       112369 non-null  object
#  4   order_approved_at              112354 non-null  object
#  5   order_delivered_carrier_date   111185 non-null  object
#  6   order_delivered_customer_date  110009 non-null  object
#  7   order_estimated_delivery_date  112369 non-null  object
#  8   order_item_id                  112369 non-null  int64
#  9   product_id                     112369 non-null  object
#  10  seller_id                      112369 non-null  object
#  11  shipping_limit_date            112369 non-null  object
# ...

# %%
df.order_id
# Out:
# 0         e481f51cbdc54678b7cc49136f2d6af7
# 1         53cdb2fc8bc7dce0b6741e2150273451
# 2         47770eb9100c2d0c44946d9cf07ec65d
# 3         949d5b44dbf5de918fe9c16f97b45f8a
# 4         ad21c59c0840e6cb83a9ceb5573f8159
#                         ...
# 112364    63943bddc261676b46f01ca7ac2f7bd8
# 112365    83c1379a015df1e13d02aae0204711ab
# 112366    11c177c8e97725db2631073c19f07b62
# 112367    11c177c8e97725db2631073c19f07b62
# 112368    66dea50a8b16d9b4dee7af250b4be1a5
# Name: order_id, Length: 112369, dtype: object

# %%
df.customer_id
# Out:
# 0         9ef432eb6251297304e76186b10a928d
# 1         b0830fb4747a6c6d20dea0b8c802d7ef
# 2         41ce2a54c0b03bf3443c3d931a367089
# 3         f88197465ea7920adcdbec7375364d82
# 4         8ab97904e6daea8866dbdbc4fb7aad2c
#                         ...
# 112364    1fca14ff2861355f6e5f14306ff977a7
# 112365    1aa71eb042121263aafbe80c1b562c9c
# 112366    b331b74b18dc79bcdf6532d51e1637c1
# 112367    b331b74b18dc79bcdf6532d51e1637c1
# 112368    edb027a75a1449115f6b43211ae02a24
# Name: customer_id, Length: 112369, dtype: object

# %%
df.order_status
# Out:
# 0         delivered
# 1         delivered
# 2         delivered
# 3         delivered
# 4         delivered
#             ...
# 112364    delivered
# 112365    delivered
# 112366    delivered
# 112367    delivered
# 112368    delivered
# Name: order_status, Length: 112369, dtype: object

# %%
df.order_purchase_timestamp
# Out:
# 0         2017-10-02 10:56:33
# 1         2018-07-24 20:41:37
# 2         2018-08-08 08:38:49
# 3         2017-11-18 19:28:06
# 4         2018-02-13 21:18:39
#                  ...
# 112364    2018-02-06 12:58:58
# 112365    2017-08-27 14:46:43
# 112366    2018-01-08 21:28:27
# 112367    2018-01-08 21:28:27
# 112368    2018-03-08 20:57:30
# Name: order_purchase_timestamp, Length: 112369, dtype: object

# %%
df.order_purchase_timestamp.str.split(" ").str[0]
# Out:
# 0         2017-10-02
# 1         2018-07-24
# 2         2018-08-08
# 3         2017-11-18
# 4         2018-02-13
#              ...
# 112364    2018-02-06
# 112365    2017-08-27
# 112366    2018-01-08
# 112367    2018-01-08
# 112368    2018-03-08
# Name: order_purchase_timestamp, Length: 112369, dtype: object

# %%
df["order_purchase_dates"] = pd.to_datetime(df["order_purchase_timestamp"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_purchase_timestamp       112369 non-null  object
#  4   order_approved_at              112354 non-null  object
#  5   order_delivered_carrier_date   111185 non-null  object
#  6   order_delivered_customer_date  110009 non-null  object
#  7   order_estimated_delivery_date  112369 non-null  object
#  8   order_item_id                  112369 non-null  int64
#  9   product_id                     112369 non-null  object
#  10  seller_id                      112369 non-null  object
#  11  shipping_limit_date            112369 non-null  object
# ...

# %%
df.drop("order_purchase_timestamp",inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_approved_at              112354 non-null  object
#  4   order_delivered_carrier_date   111185 non-null  object
#  5   order_delivered_customer_date  110009 non-null  object
#  6   order_estimated_delivery_date  112369 non-null  object
#  7   order_item_id                  112369 non-null  int64
#  8   product_id                     112369 non-null  object
#  9   seller_id                      112369 non-null  object
#  10  shipping_limit_date            112369 non-null  object
#  11  price                          112369 non-null  float64
# ...

# %%
df.order_approved_at
# Out:
# 0         2017-10-02 11:07:15
# 1         2018-07-26 03:24:27
# 2         2018-08-08 08:55:23
# 3         2017-11-18 19:45:59
# 4         2018-02-13 22:20:29
#                  ...
# 112364    2018-02-06 13:10:37
# 112365    2017-08-27 15:04:16
# 112366    2018-01-08 21:36:21
# 112367    2018-01-08 21:36:21
# 112368    2018-03-09 11:20:28
# Name: order_approved_at, Length: 112369, dtype: object

# %%
df.drop("order_approved_at",inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_carrier_date   111185 non-null  object
#  4   order_delivered_customer_date  110009 non-null  object
#  5   order_estimated_delivery_date  112369 non-null  object
#  6   order_item_id                  112369 non-null  int64
#  7   product_id                     112369 non-null  object
#  8   seller_id                      112369 non-null  object
#  9   shipping_limit_date            112369 non-null  object
#  10  price                          112369 non-null  float64
#  11  freight_value                  112369 non-null  float64
# ...

# %%
df.order_delivered_carrier_date
# Out:
# 0         2017-10-04 19:55:00
# 1         2018-07-26 14:31:00
# 2         2018-08-08 13:50:00
# 3         2017-11-22 13:39:59
# 4         2018-02-14 19:46:34
#                  ...
# 112364    2018-02-07 23:22:42
# 112365    2017-08-28 20:52:26
# 112366    2018-01-12 15:35:03
# 112367    2018-01-12 15:35:03
# 112368    2018-03-09 22:11:59
# Name: order_delivered_carrier_date, Length: 112369, dtype: object

# %%
df.order_delivered_customer_date
# Out:
# 0         2017-10-10 21:25:13
# 1         2018-08-07 15:27:45
# 2         2018-08-17 18:06:29
# 3         2017-12-02 00:28:42
# 4         2018-02-16 18:17:02
#                  ...
# 112364    2018-02-28 17:37:56
# 112365    2017-09-21 11:24:17
# 112366    2018-01-25 23:32:54
# 112367    2018-01-25 23:32:54
# 112368    2018-03-16 13:08:30
# Name: order_delivered_customer_date, Length: 112369, dtype: object

# %%
df.order_estimated_delivery_date
# Out:
# 0         2017-10-18 00:00:00
# 1         2018-08-13 00:00:00
# 2         2018-09-04 00:00:00
# 3         2017-12-15 00:00:00
# 4         2018-02-26 00:00:00
#                  ...
# 112364    2018-03-02 00:00:00
# 112365    2017-09-27 00:00:00
# 112366    2018-02-15 00:00:00
# 112367    2018-02-15 00:00:00
# 112368    2018-04-03 00:00:00
# Name: order_estimated_delivery_date, Length: 112369, dtype: object

# %%
df.drop(["order_delivered_carrier_date","order_estimated_delivery_date"],inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  object
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   shipping_limit_date            112369 non-null  object
#  8   price                          112369 non-null  float64
#  9   freight_value                  112369 non-null  float64
#  10  product_category_name          110771 non-null  object
#  11  product_name_lenght            110771 non-null  float64
# ...

# %%
df["order_delivered_customer_date"].str.split(" ").str[0]
# Out:
# 0         2017-10-10
# 1         2018-08-07
# 2         2018-08-17
# 3         2017-12-02
# 4         2018-02-16
#              ...
# 112364    2018-02-28
# 112365    2017-09-21
# 112366    2018-01-25
# 112367    2018-01-25
# 112368    2018-03-16
# Name: order_delivered_customer_date, Length: 112369, dtype: object

# %%
df["order_delivered_customer_date"] =pd.to_datetime(df["order_delivered_customer_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   shipping_limit_date            112369 non-null  object
#  8   price                          112369 non-null  float64
#  9   freight_value                  112369 non-null  float64
#  10  product_category_name          110771 non-null  object
#  11  product_name_lenght            110771 non-null  float64
# ...

# %%
df.product_id
# Out:
# 0         87285b34884572647811a353c7ac498a
# 1         595fac2a385ac33a80bd5114aec74eb8
# 2         aa4383b373c6aca5d8797843e5594415
# 3         d0b61bfb1de832b15ba9d266ca96e5b0
# 4         65266b2da20d04dbe00c5c2d3bb7859e
#                         ...
# 112364    f1d4ce8c6dd66c47bbaa8c6781c2a923
# 112365    b80910977a37536adeddd63663f916ad
# 112366    d1c427060a0f73f6b889a5c7c61f2ac4
# 112367    d1c427060a0f73f6b889a5c7c61f2ac4
# 112368    006619bbed68b000c8ba3f8725d5409e
# Name: product_id, Length: 112369, dtype: object

# %%
df.seller_id
# Out:
# 0         3504c0cb71d7fa48d967e0e4c94d59d9
# 1         289cdb325fb7e7f891c38608bf9e0962
# 2         4869f7a5dfa277a7dca6462dcf3b52b2
# 3         66922902710d126a0e7d26b0e3805106
# 4         2c9e548be18521d1c43cde1c582c6de8
#                         ...
# 112364    1f9ab4708f3056ede07124aad39a2554
# 112365    d50d79cb34e38265a8649c383dcffd48
# 112366    a1043bafd471dff536d0c462352beb48
# 112367    a1043bafd471dff536d0c462352beb48
# 112368    ececbfcff9804a2d6b40f589df8eef2b
# Name: seller_id, Length: 112369, dtype: object

# %%
df.shipping_limit_date
# Out:
# 0         2017-10-06 11:07:15
# 1         2018-07-30 03:24:27
# 2         2018-08-13 08:55:23
# 3         2017-11-23 19:45:59
# 4         2018-02-19 20:31:37
#                  ...
# 112364    2018-02-12 13:10:37
# 112365    2017-09-05 15:04:16
# 112366    2018-01-12 21:36:21
# 112367    2018-01-12 21:36:21
# 112368    2018-03-15 10:55:42
# Name: shipping_limit_date, Length: 112369, dtype: object

# %%
df["shipping_limit_date"].str.split(" ").str[0]
# Out:
# 0         2017-10-06
# 1         2018-07-30
# 2         2018-08-13
# 3         2017-11-23
# 4         2018-02-19
#              ...
# 112364    2018-02-12
# 112365    2017-09-05
# 112366    2018-01-12
# 112367    2018-01-12
# 112368    2018-03-15
# Name: shipping_limit_date, Length: 112369, dtype: object

# %%
df["order_shipping_date"] = pd.to_datetime(df["shipping_limit_date"])

# %%
df.drop("shipping_limit_date",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          110771 non-null  object
#  10  product_name_lenght            110771 non-null  float64
#  11  product_description_lenght     110771 non-null  float64
# ...

# %%
df.product_category_name
# Out:
# 0          utilidades_domesticas
# 1                     perfumaria
# 2                     automotivo
# 3                       pet_shop
# 4                      papelaria
#                    ...
# 112364                     bebes
# 112365        eletrodomesticos_2
# 112366    informatica_acessorios
# 112367    informatica_acessorios
# 112368              beleza_saude
# Name: product_category_name, Length: 112369, dtype: object

# %%
df.product_name_lenght
# Out:
# 0         40.0
# 1         29.0
# 2         46.0
# 3         59.0
# 4         38.0
#           ...
# 112364    52.0
# 112365    51.0
# 112366    59.0
# 112367    59.0
# 112368    45.0
# Name: product_name_lenght, Length: 112369, dtype: float64

# %%
df.drop("product_name_lenght",inplace=True,axis=1)

# %%
df.product_description_lenght
# Out:
# 0          268.0
# 1          178.0
# 2          232.0
# 3          468.0
# 4          316.0
#            ...
# 112364     828.0
# 112365     500.0
# 112366    1893.0
# 112367    1893.0
# 112368     569.0
# Name: product_description_lenght, Length: 112369, dtype: float64

# %%
df.drop("product_description_lenght",inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          110771 non-null  object
#  10  product_photos_qty             110771 non-null  float64
#  11  product_weight_g               112351 non-null  float64
# ...

# %%
df.drop(["product_photos_qty","product_weight_g","product_length_cm","product_width_cm","product_height_cm"],inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          110771 non-null  object
#  10  customer_unique_id             112369 non-null  object
#  11  customer_zip_code_prefix       112369 non-null  int64
# ...

# %%
df.customer_unique_id
# Out:
# 0         7c396fd4830fd04220f754e42b4e5bff
# 1         af07308b275d755c9edb36a90c618231
# 2         3a653a41f6f9fc3d2a113cf8398680e8
# 3         7c142cf63193a1473d2e66489a9ae977
# 4         72632f0f9dd73dfee390c9b22eb56dd6
#                         ...
# 112364    da62f9e57a76d978d02ab5362c509660
# 112365    737520a9aad80b3fbbdad19b66b37b30
# 112366    5097a5312c8b157bb7be58ae360ef43c
# 112367    5097a5312c8b157bb7be58ae360ef43c
# 112368    60350aa974b26ff12caad89e55993bd6
# Name: customer_unique_id, Length: 112369, dtype: object

# %%
df.customer_zip_code_prefix
# Out:
# 0          3149
# 1         47813
# 2         75265
# 3         59296
# 4          9195
#           ...
# 112364    11722
# 112365    45920
# 112366    28685
# 112367    28685
# 112368    83750
# Name: customer_zip_code_prefix, Length: 112369, dtype: int64

# %%
df.customer_city
# Out:
# 0                       sao paulo
# 1                       barreiras
# 2                      vianopolis
# 3         sao goncalo do amarante
# 4                     santo andre
#                    ...
# 112364               praia grande
# 112365                nova vicosa
# 112366                    japuiba
# 112367                    japuiba
# 112368                       lapa
# Name: customer_city, Length: 112369, dtype: object

# %%
df.customer_state
# Out:
# 0         SP
# 1         BA
# 2         GO
# 3         RN
# 4         SP
#           ..
# 112364    SP
# 112365    BA
# 112366    RJ
# 112367    RJ
# 112368    PR
# Name: customer_state, Length: 112369, dtype: object

# %%
df.review_id
# Out:
# 0         a54f0611adc9ed256b57ede6b6eb5114
# 1         8d5266042046a06655c8db133d120ba5
# 2         e73b67b67587f7644d5bd1a52deb1b01
# 3         359d03e676b3c069f62cadba8dd3f6e8
# 4         e50934924e227544ba8246aeb3770dd4
#                         ...
# 112364    29bb71b2760d0f876dfa178a76bc4734
# 112365    371579771219f6db2d830d50805977bb
# 112366    8ab6855b9fe9b812cd03a480a25058a1
# 112367    8ab6855b9fe9b812cd03a480a25058a1
# 112368    dc9c59b4688062c25758c2be4cafc523
# Name: review_id, Length: 112369, dtype: object

# %%
df.review_score
# Out:
# 0         4
# 1         4
# 2         5
# 3         5
# 4         5
#          ..
# 112364    4
# 112365    5
# 112366    2
# 112367    2
# 112368    5
# Name: review_score, Length: 112369, dtype: int64

# %%
df.drop("review_id",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          110771 non-null  object
#  10  customer_unique_id             112369 non-null  object
#  11  customer_zip_code_prefix       112369 non-null  int64
# ...

# %%
df.review_comment_title
# Out:
# 0                      NaN
# 1         Muito boa a loja
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                 ...
# 112364                 NaN
# 112365                 NaN
# 112366                 NaN
# 112367                 NaN
# 112368                 NaN
# Name: review_comment_title, Length: 112369, dtype: object

# %% [markdown]
# # Ye dates sirf ye batati hain ki customer ko review dene ke liye form kab bheja gaya aur usne kab form bhara. Humein isse koi farq nahi padta. Humein sirf isse matlab hai ki usne rating kitni di

# %%
df.drop(["review_comment_title","review_comment_message"],axis=1,inplace=True)

# %%
df.review_creation_date
# Out:
# 0         2017-10-11 00:00:00
# 1         2018-08-08 00:00:00
# 2         2018-08-18 00:00:00
# 3         2017-12-03 00:00:00
# 4         2018-02-17 00:00:00
#                  ...
# 112364    2018-03-01 00:00:00
# 112365    2017-09-22 00:00:00
# 112366    2018-01-26 00:00:00
# 112367    2018-01-26 00:00:00
# 112368    2018-03-17 00:00:00
# Name: review_creation_date, Length: 112369, dtype: object

# %%
df.drop(["review_creation_date","review_answer_timestamp"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  110009 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          110771 non-null  object
#  10  customer_unique_id             112369 non-null  object
#  11  customer_zip_code_prefix       112369 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_delivered_customer_date    2360
# order_item_id                       0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# product_category_name            1598
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# review_score                        0
# payment_value                       0
# order_purchase_dates                0
# order_shipping_date                 0
# dtype: int64

# %%
df[df["order_delivered_customer_date"].isna()]
# Out:
#                                 order_id                       customer_id  \
# 6       136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 45      ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 117     0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 147     15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 191     36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# ...                                  ...                               ...
# 112027  aea0db338150b526dde24f6fd953a5ed  379a02efdc6a56bd27f99b95fc2f6c06
# 112036  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 112037  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 112078  636cdd02667dc8d76d9296bf20a6890a  c162256b133c76f79181ce61d66545db
# 112231  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
#
#        order_status order_delivered_customer_date  order_item_id  \
# ...

# %%
avg_dlvrd_customer_date = (df['order_delivered_customer_date'] -df["order_purchase_dates"]).mean()
df["order_delivered_customer_date"] = df["order_delivered_customer_date"].fillna(df['order_purchase_dates']+avg_dlvrd_customer_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  112369 non-null  datetime64[ns]
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          110771 non-null  object
#  10  customer_unique_id             112369 non-null  object
#  11  customer_zip_code_prefix       112369 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_delivered_customer_date       0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# price                               0
# freight_value                       0
# product_category_name            1598
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# review_score                        0
# payment_value                       0
# order_purchase_dates                0
# order_shipping_date                 0
# avg_dlvrd_customer_date             0
# dtype: int64

# %%
df[df["product_category_name"].isna()]
# Out:
#                                 order_id                       customer_id  \
# 6       136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 121     bfe42c22ecbf90bc9f35cf591270b6a7  803ac05904124294f8767894d6da532b
# 210     58ac1947c1a9067b9f416cba6d844a3f  ee8e1d37f563ecc11cc4dcb4dfd794c2
# 262     e22b71f6e4a481445ec4527cb4c405f7  1faf89c8f142db3fca6cf314c51a37b6
# 301     a094215e786240fcfefb83d18036a1cd  86acfb656743da0c113d176832c9d535
# ...                                  ...                               ...
# 111931  020f8f4df303ae8aa39b806b766d2681  d588273738545bc6a0d30971bf72e938
# 111947  1a10e938a1c7d8e5eecc3380f71ca76b  8a81607347c25d881d995d94de6ad824
# 112117  e33865519137f5737444109ae8438633  64b086bdcc54458af3ea3bd838db54a5
# 112124  f0dd9af88d8ef5a8e4670fbbedaf19c4  30ddb50bd22ee927ebe308ea3da60735
# 112130  272874573723eec18f23c0471927d778  48e080c8001e92ebea2b64e474f91a60
#
#        order_status order_delivered_customer_date  order_item_id  \
# ...

# %%
df["product_category_name"] = df["product_category_name"].fillna("unknown")

# %%
df.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_delivered_customer_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# price                            0
# freight_value                    0
# product_category_name            0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# review_score                     0
# payment_value                    0
# order_purchase_dates             0
# order_shipping_date              0
# avg_dlvrd_customer_date          0
# dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ye line aapke data ko seedha Google Drive me save kar degi
df.to_csv('/content/drive/MyDrive/olist_final_clean_data.csv', index=False)
print("Data Drive me safe ho gaya!")
# Out:
# Data Drive me safe ho gaya!

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Seedha apna kal wala clean data read karein
df = pd.read_csv('/content/drive/MyDrive/olist_final_clean_data.csv')
# Out:
# Mounted at /content/drive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112369 non-null  object
#  1   customer_id                    112369 non-null  object
#  2   order_status                   112369 non-null  object
#  3   order_delivered_customer_date  112369 non-null  object
#  4   order_item_id                  112369 non-null  int64
#  5   product_id                     112369 non-null  object
#  6   seller_id                      112369 non-null  object
#  7   price                          112369 non-null  float64
#  8   freight_value                  112369 non-null  float64
#  9   product_category_name          112369 non-null  object
#  10  customer_unique_id             112369 non-null  object
#  11  customer_zip_code_prefix       112369 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_delivered_customer_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# price                            0
# freight_value                    0
# product_category_name            0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# review_score                     0
# payment_value                    0
# order_purchase_dates             0
# order_shipping_date              0
# avg_dlvrd_customer_date          0
# dtype: int64

# %%
df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status  order_delivered_customer_date  order_item_id  \
# 0    delivered  2017-10-10 21:25:13.000000000              1
# 1    delivered  2018-08-07 15:27:45.000000000              1
# 2    delivered  2018-08-17 18:06:29.000000000              1
# 3    delivered  2017-12-02 00:28:42.000000000              1
# 4    delivered  2018-02-16 18:17:02.000000000              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %%
df = df.rename(columns={"order_delivered_customer_date":"order_delivered_date"})
df["order_delivered_date"] = df["order_delivered_date"].str.split(" ").str[0]
df["order_purchase_dates"] = df["order_purchase_dates"].str.split(" ").str[0]
df["order_shipping_dates"] = df["order_shipping_date"].str.split(" ").str[0]

# %%
df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_delivered_date  order_item_id  \
# 0    delivered           2017-10-10              1
# 1    delivered           2018-08-07              1
# 2    delivered           2018-08-17              1
# 3    delivered           2017-12-02              1
# 4    delivered           2018-02-16              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %%
df.drop("order_shipping_date",axis=1,inplace=True)

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_delivered_date  order_item_id  \
# 0    delivered           2017-10-10              1
# 1    delivered           2018-08-07              1
# 2    delivered           2018-08-17              1
# 3    delivered           2017-12-02              1
# 4    delivered           2018-02-16              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112369 non-null  object
#  1   customer_id               112369 non-null  object
#  2   order_status              112369 non-null  object
#  3   order_delivered_date      112369 non-null  object
#  4   order_item_id             112369 non-null  int64
#  5   product_id                112369 non-null  object
#  6   seller_id                 112369 non-null  object
#  7   price                     112369 non-null  float64
#  8   freight_value             112369 non-null  float64
#  9   product_category_name     112369 non-null  object
#  10  customer_unique_id        112369 non-null  object
#  11  customer_zip_code_prefix  112369 non-null  int64
#  12  customer_city             112369 non-null  object
# ...

# %%
df.drop("avg_dlvrd_customer_date", inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112369 non-null  object
#  1   customer_id               112369 non-null  object
#  2   order_status              112369 non-null  object
#  3   order_delivered_date      112369 non-null  object
#  4   order_item_id             112369 non-null  int64
#  5   product_id                112369 non-null  object
#  6   seller_id                 112369 non-null  object
#  7   price                     112369 non-null  float64
#  8   freight_value             112369 non-null  float64
#  9   product_category_name     112369 non-null  object
#  10  customer_unique_id        112369 non-null  object
#  11  customer_zip_code_prefix  112369 non-null  int64
#  12  customer_city             112369 non-null  object
# ...

# %%
df["order_delivered_date"] = pd.to_datetime(df["order_delivered_date"])

# %%
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 112364  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 112365  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 112366  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112367  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 112368  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_delivered_date  order_item_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112369 non-null  object
#  1   customer_id               112369 non-null  object
#  2   order_status              112369 non-null  object
#  3   order_delivered_date      112369 non-null  datetime64[ns]
#  4   order_item_id             112369 non-null  int64
#  5   product_id                112369 non-null  object
#  6   seller_id                 112369 non-null  object
#  7   price                     112369 non-null  float64
#  8   freight_value             112369 non-null  float64
#  9   product_category_name     112369 non-null  object
#  10  customer_unique_id        112369 non-null  object
#  11  customer_zip_code_prefix  112369 non-null  int64
#  12  customer_city             112369 non-null  object
# ...

# %%
df["order_purchase_dates"] = pd.to_datetime(df["order_purchase_dates"])
df["order_shipping_dates"] = pd.to_datetime(df["order_shipping_dates"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112369 non-null  object
#  1   customer_id               112369 non-null  object
#  2   order_status              112369 non-null  object
#  3   order_delivered_date      112369 non-null  datetime64[ns]
#  4   order_item_id             112369 non-null  int64
#  5   product_id                112369 non-null  object
#  6   seller_id                 112369 non-null  object
#  7   price                     112369 non-null  float64
#  8   freight_value             112369 non-null  float64
#  9   product_category_name     112369 non-null  object
#  10  customer_unique_id        112369 non-null  object
#  11  customer_zip_code_prefix  112369 non-null  int64
#  12  customer_city             112369 non-null  object
# ...

# %%
df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_delivered_date  order_item_id  \
# 0    delivered           2017-10-10              1
# 1    delivered           2018-08-07              1
# 2    delivered           2018-08-17              1
# 3    delivered           2017-12-02              1
# 4    delivered           2018-02-16              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %% [markdown]
# # ASSUMPTION :  har product par 20% profit margin dete hai discount ke liye

# %%
df["estimated_profit"] = df["price"]*0.20
df["total_bill"] = df["price"] + df["freight_value"]
df["distcount_amount"] = df["total_bill"] -df["payment_value"]

# %%
df["distcount_amount"] = df["distcount_amount"].apply(lambda x : x if x > 0 else 0 )

# %%
df.drop("total_bill",axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_delivered_date  order_item_id  \
# 0    delivered           2017-10-10              1
# 1    delivered           2018-08-07              1
# 2    delivered           2018-08-17              1
# 3    delivered           2017-12-02              1
# 4    delivered           2018-02-16              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112369 entries, 0 to 112368
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   order_id                  112369 non-null  object
#  1   customer_id               112369 non-null  object
#  2   order_status              112369 non-null  object
#  3   order_delivered_date      112369 non-null  datetime64[ns]
#  4   order_item_id             112369 non-null  int64
#  5   product_id                112369 non-null  object
#  6   seller_id                 112369 non-null  object
#  7   price                     112369 non-null  float64
#  8   freight_value             112369 non-null  float64
#  9   product_category_name     112369 non-null  object
#  10  customer_unique_id        112369 non-null  object
#  11  customer_zip_code_prefix  112369 non-null  int64
#  12  customer_city             112369 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# order_id                    0
# customer_id                 0
# order_status                0
# order_delivered_date        0
# order_item_id               0
# product_id                  0
# seller_id                   0
# price                       0
# freight_value               0
# product_category_name       0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# review_score                0
# payment_value               0
# order_purchase_dates        0
# order_shipping_dates        0
# estimated_profit            0
# distcount_amount            0
# dtype: int64

# %%
from google.colab import files
df.to_csv("olist_brazilian_clean_data.csv",index=False)
files.download("olist_brazilian_clean_data.csv")

# %%
cat_col = [feature for feature in df.columns if df[feature].dtype=="object"]

# %%
cat_col
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'product_id',
#  'seller_id',
#  'product_category_name',
#  'customer_unique_id',
#  'customer_city',
#  'customer_state']

# %%
num_col = [feature for feature in df.columns if df[feature].dtype!="object"]

# %%
num_col
# Out:
# ['order_delivered_date',
#  'order_item_id',
#  'price',
#  'freight_value',
#  'customer_zip_code_prefix',
#  'review_score',
#  'payment_value',
#  'order_purchase_dates',
#  'order_shipping_dates',
#  'estimated_profit',
#  'distcount_amount']

# %%
df.payment_value.sum()
# Out:
# np.float64(20187928.699999996)

# %%
df.duplicated().sum()
# Out:
# np.int64(399)

# %%
df[df.duplicated()]
# Out:
#                                 order_id                       customer_id  \
# 453     ac7a92560a9e99f0a0ab4988102f491b  6abf781c5304890987047e9aa239caa8
# 624     7845a2492ab1b4f2cf3d56c7b8da1446  386e96046ce0e77e5c9a9a4e818da93c
# 699     714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 761     acbe07f22f29ad7e5a78f30008cc6ec7  b4afeb58ac51bc903c5362286c6a5cfe
# 763     acbe07f22f29ad7e5a78f30008cc6ec7  b4afeb58ac51bc903c5362286c6a5cfe
# ...                                  ...                               ...
# 111676  66f943fd426ac8716ef6b6b97ace8bd8  592ef413ebc8f70a779b9282d2ea6020
# 111891  76de574e14e58baded25a12dce8075c1  3dc99b2fcf41c0898cfc7f38c2fefe5e
# 111920  2fcdb0c004a2a538d3dd724ea76916bd  cf826be53b1fe4a39bc33c7f5f827835
# 111961  dbfa3d8c05cc5d84083fc259a9feb5bc  92fc29e76e4da7c1b189ab092d4c3756
# 112105  79ce3a0a9eba49ff442b392ab05349a4  3b979b88fbf88354add6870de52d007b
#
#        order_status order_delivered_date  order_item_id  \
# ...

# %%
cat_col
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'product_id',
#  'seller_id',
#  'product_category_name',
#  'customer_unique_id',
#  'customer_city',
#  'customer_state']

# %%
df.order_id.nunique()
# Out:
# 97916

# %%
df.payment_value.mean()
# Out:
# np.float64(179.65745623793035)

# %%
df.review_score.mean()
# Out:
# np.float64(4.032553462253825)

# %%
df.groupby(["product_category_name"])["payment_value"].sum().sort_values(ascending=False)[:5]
# Out:
# product_category_name
# cama_mesa_banho           1725465.67
# beleza_saude              1646292.53
# informatica_acessorios    1592611.66
# moveis_decoracao          1427214.01
# relogios_presentes        1420682.17
# Name: payment_value, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
df1 = df.groupby(["product_category_name"])["payment_value"].sum().sort_values(ascending=False)[:5]
ax = sns.barplot(x=df1.index,y=df1.values,palette="rocket")
for container in ax.containers:
  ax.bar_label(container)
plt.xticks(rotation=45)
plt.xlabel("product_name")
plt.ylabel("total_payment_value")
plt.title("total_sales_by_product_name")
plt.show()

# %% [markdown]
# # sabse jyada cama_mesa_banho me order hua hai

# %%
cat_col
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'product_id',
#  'seller_id',
#  'product_category_name',
#  'customer_unique_id',
#  'customer_city',
#  'customer_state']

# %%
df.groupby(["customer_state"])["payment_value"].sum().sort_values(ascending=False).head(5)
# Out:
# customer_state
# SP    7599878.17
# RJ    2741288.10
# MG    2313559.77
# RS    1151947.74
# PR    1066626.81
# Name: payment_value, dtype: float64

# %% [markdown]
# # sabse jyada SP	7599878.17
# # or sabse kam RR	12462.21

# %%
df.groupby(["customer_state"])["payment_value"].sum().sort_values(ascending=True).head(5)
# Out:
# customer_state
# RR    12462.21
# AP    21572.32
# AC    24984.86
# AM    34567.86
# RO    65836.95
# Name: payment_value, dtype: float64

# %%
df2 = df.groupby(["customer_state"])["payment_value"].sum().sort_values(ascending=False).head(5)
ax = sns.barplot(x=df2.values,y=df2.index , palette="viridis" )
for c in ax.containers:
  ax.bar_label(c)
plt.xlabel("payment value")
plt.ylabel("state")
plt.title("state wise payment")
plt.show()

# %%
sns.countplot(x=df["review_score"],palette="coolwarm")
plt.xlabel("review")
plt.ylabel("count")
plt.title("overall rating review")
plt.show()

# %% [markdown]
# # sabse jyada 5 rating mili hai yani ki product shi hai or timer per deliverd hua hai baki jisme 1 2 3 isme ya to time per deliverd nhi hua hai ya fir product damage ho skta hai

# %%
df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_delivered_date  order_item_id  \
# 0    delivered           2017-10-10              1
# 1    delivered           2018-08-07              1
# 2    delivered           2018-08-17              1
# 3    delivered           2017-12-02              1
# 4    delivered           2018-02-16              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %%
df["order_purchase_day"] = df["order_purchase_dates"].dt.day
df["order_purchase_month"] = df["order_purchase_dates"].dt.month
df["order_purchase_year"] = df["order_purchase_dates"].dt.year

# %%
df["order_delivered_day"] = df["order_delivered_date"].dt.day
df["order_delivered_month"] = df["order_delivered_date"].dt.month
df["order_delivered_year"] = df["order_delivered_date"].dt.year

# %%
df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_delivered_date  order_item_id  \
# 0    delivered           2017-10-10              1
# 1    delivered           2018-08-07              1
# 2    delivered           2018-08-17              1
# 3    delivered           2017-12-02              1
# 4    delivered           2018-02-16              1
#
#                          product_id                         seller_id   price  \
# 0  87285b34884572647811a353c7ac498a  3504c0cb71d7fa48d967e0e4c94d59d9   29.99
# ...

# %%
# new clean file dwonload
from google.colab import files
df.to_csv("olist_brazilian_final_clean_data.csv",index=False)
files.download("olist_brazilian_final_clean_data.csv")

# %%
# 1. Year ke hisab se total sum
yoy_growth = df.groupby(["order_purchase_year"])["payment_value"].sum().reset_index()
yoy_growth["yoy_growth_%"] = yoy_growth["payment_value"].pct_change() * 100

# %%
# 3. Result dekhein
yoy_growth
# Out:
#    order_purchase_year  payment_value  yoy_growth_%
# 0                 2016       73238.88           NaN
# 1                 2017     9095490.37  12318.937004
# 2                 2018    11019199.45     21.150141

# %%
# mom

mom_growth = df.groupby(["order_purchase_month"])["payment_value"].sum().reset_index()
mom_growth["mom_growth_%"] = mom_growth["payment_value"].pct_change()*100

# %%
mom_growth
# Out:
#     order_purchase_month  payment_value  mom_growth_%
# 0                      1     1591214.33           NaN
# 1                      2     1650455.90      3.723042
# 2                      3     1990070.24     20.577002
# 3                      4     1989295.87     -0.038912
# 4                      5     2221998.93     11.697760
# 5                      6     1895634.60    -14.687871
# 6                      7     2074365.39      9.428547
# 7                      8     2049528.99     -1.197301
# 8                      9     1017947.51    -50.332612
# 9                     10     1096703.77      7.736770
# 10                    11     1579407.32     44.014032
# 11                    12     1031305.85    -34.702984
